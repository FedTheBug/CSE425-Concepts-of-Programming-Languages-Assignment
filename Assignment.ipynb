# %%
import pandas as pd
import numpy as np
df= pd.read_csv("NCHS_-_Leading_Causes_of_Death__United_States.csv")
df
# Out:
#        Year                                     113 Cause Name  \
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
df.tail()
# Out:
#        Year                                     113 Cause Name  \
# 10291  2003  Accidents (unintentional injuries) (V01-X59,Y8...
# 10292  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 10293  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 10294  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 10295  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name    State  Deaths  Age-adjusted Death Rate
# 10291  Unintentional injuries  Wyoming     273                     55.1
# 10292  Unintentional injuries  Wyoming     289                     58.1
# 10293  Unintentional injuries  Wyoming     272                     55.5
# 10294  Unintentional injuries  Wyoming     245                     50.8
# 10295  Unintentional injuries  Wyoming     258                     52.8

# %%
df.sample(5)
# Out:
#       Year                                     113 Cause Name  \
# 4425  2016                        Diabetes mellitus (E10-E14)
# 9106  2015  Intentional self-harm (suicide) (*U03,X60-X84,...
# 4641  2016                        Diabetes mellitus (E10-E14)
# 4819  2000        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 1762  2015                          Alzheimer's disease (G30)
#
#                Cause Name       State  Deaths  Age-adjusted Death Rate
# 4425             Diabetes        Ohio    3568                     24.6
# 9106              Suicide        Ohio    1650                     13.9
# 4641             Diabetes    Virginia    2062                     21.7
# 4819        Heart disease  California   68426                    239.9
# 1762  Alzheimer's disease       Texas    8903                     38.2

# %%
df[['Year', '113 Cause Name']]
# Out:
#        Year                                     113 Cause Name
# 0      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     2016  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
df.113Cause Name == 'Diabetes mellitus (E10-E14)'
# Out:
#   File "<ipython-input-12-ee2aef7ab042>", line 1
#     df.113Cause Name == 'Diabetes mellitus (E10-E14)'
#          ^
# SyntaxError: invalid syntax
